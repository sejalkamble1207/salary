# %%
import pandas as pd

# %%
df = pd.read_csv(r"Desktop/Salaries.csv")
df
# Out:
# C:\Users\kle\AppData\Local\Temp\ipykernel_5188\1882943725.py:1: DtypeWarning: Columns (0: BasePay, 1: OvertimePay, 2: OtherPay, 3: Unnamed: 9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"Desktop/Salaries.csv")
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay   TotalPay  Year         Agency Unnamed: 9
# 0                0.0     400184.25  567595.43  2011  San Francisco        NaN
# 1          245131.88     137811.38  538909.28  2011  San Francisco        NaN
# 2          106088.18       16452.6  335279.91  2011  San Francisco        NaN
# 3           56120.71      198306.9  332343.61  2011  San Francisco        NaN
# 4             9737.0     182234.59  326373.19  2011  San Francisco        NaN
# ...              ...           ...        ...   ...            ...        ...
# 148649             0             0       0.00  2014  San Francisco         PT
# 148650  Not Provided  Not Provided       0.00  2014  San Francisco        NaN
# 148651  Not Provided  Not Provided       0.00  2014  San Francisco        NaN
# 148652  Not Provided  Not Provided       0.00  2014  San Francisco        NaN
# 148653             0       -618.13    -618.13  2014  San Francisco         PT
#
# [148654 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Id            148654 non-null  int64
#  1   EmployeeName  148654 non-null  str
#  2   JobTitle      148654 non-null  str
#  3   BasePay       148049 non-null  object
#  4   OvertimePay   148654 non-null  object
#  5   OtherPay      148654 non-null  object
#  6   TotalPay      148654 non-null  float64
#  7   Year          148654 non-null  int64
#  8   Agency        148654 non-null  str
#  9   Unnamed: 9    38119 non-null   str
# dtypes: float64(1), int64(2), object(3), str(4)
# memory usage: 11.3+ MB

# %%
df.describe()
# Out:
#                   Id       TotalPay           Year
# count  148654.000000  148654.000000  148654.000000
# mean    74327.500000   74768.321972    2012.522643
# std     42912.857795   50517.005274       1.117538
# min         1.000000    -618.130000    2011.000000
# 25%     37164.250000   36168.995000    2012.000000
# 50%     74327.500000   71426.610000    2013.000000
# 75%    111490.750000  105839.135000    2014.000000
# max    148654.000000  567595.430000    2014.000000

# %%
df.nunique()
# Out:
# Id              148654
# EmployeeName    110811
# JobTitle          2159
# BasePay         109900
# OvertimePay      66555
# OtherPay         84968
# TotalPay        138486
# Year                 4
# Agency               1
# Unnamed: 9           2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id                   0
# EmployeeName         0
# JobTitle             0
# BasePay            605
# OvertimePay          0
# OtherPay             0
# TotalPay             0
# Year                 0
# Agency               0
# Unnamed: 9      110535
# dtype: int64

# %%
df.shape
# Out:
# (148654, 10)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay   TotalPay  Year         Agency Unnamed: 9
# 0  167411.18         0.0  400184.25  567595.43  2011  San Francisco        NaN
# 1  155966.02   245131.88  137811.38  538909.28  2011  San Francisco        NaN
# 2  212739.13   106088.18    16452.6  335279.91  2011  San Francisco        NaN
# 3    77916.0    56120.71   198306.9  332343.61  2011  San Francisco        NaN
# 4   134401.6      9737.0  182234.59  326373.19  2011  San Francisco        NaN

# %%
df.tail()
# Out:
#             Id   EmployeeName                    JobTitle       BasePay  \
# 148649  148650  Roy I Tillery                   Custodian             0
# 148650  148651   Not provided                Not provided  Not Provided
# 148651  148652   Not provided                Not provided  Not Provided
# 148652  148653   Not provided                Not provided  Not Provided
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay  TotalPay  Year         Agency Unnamed: 9
# 148649             0             0      0.00  2014  San Francisco         PT
# 148650  Not Provided  Not Provided      0.00  2014  San Francisco        NaN
# 148651  Not Provided  Not Provided      0.00  2014  San Francisco        NaN
# 148652  Not Provided  Not Provided      0.00  2014  San Francisco        NaN
# 148653             0       -618.13   -618.13  2014  San Francisco         PT

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Length: 148654, dtype: bool

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'TotalPay', 'Year', 'Agency', 'Unnamed: 9'],
#       dtype='str')

# %%
df.dropna(subset=['BasePay'],inplace=True)

# %%
df = df.drop(columns=['Unnamed: 9'])

# %%
df.isnull().sum()
# Out:
# Id              0
# EmployeeName    0
# JobTitle        0
# BasePay         0
# OvertimePay     0
# OtherPay        0
# TotalPay        0
# Year            0
# Agency          0
# dtype: int64

# %%
list(df.columns)
# Out:
# ['Id',
#  'EmployeeName',
#  'JobTitle',
#  'BasePay',
#  'OvertimePay',
#  'OtherPay',
#  'TotalPay',
#  'Year',
#  'Agency']

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df["TotalPay"] = pd.to_numeric(df["TotalPay"], errors="coerce")

sns.histplot(df["TotalPay"].dropna())
plt.show()

sns.boxplot(x=df["TotalPay"].dropna())
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df)
plt.show()

# %%
df['TotalPay'].value_counts()
# Out:
# TotalPay
#  18594.00     82
#  0.00         80
#  123290.70    56
#  132242.50    49
#  105489.00    42
#               ..
#  13.77         1
#  13.35         1
#  12.89         1
#  6.00          1
# -618.13        1
# Name: count, Length: 138188, dtype: int64

# %%
import numpy as np
df['OtherPay'] = df['OtherPay'].replace('Not Provided', np.nan)
df['OtherPay'] = pd.to_numeric(df['OtherPay'], errors='coerce')
plt.figure(figsize=(6,3))
sns.scatterplot(data=df, x='JobTitle', y='OtherPay', hue='TotalPay')
plt.title("JobTitle vs OtherPay by TotalPay")
plt.show()

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Year', palette='viridis')
plt.title('Count of Employees by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kle\AppData\Local\Temp\ipykernel_5188\1465107327.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Year', palette='viridis')

# %%
cat = df.select_dtypes(include='object')
cat
# Out:
# C:\Users\kle\AppData\Local\Temp\ipykernel_5188\4073560141.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat = df.select_dtypes(include='object')
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay         Agency
# 0          167411.18           0.0  San Francisco
# 1          155966.02     245131.88  San Francisco
# 2          212739.13     106088.18  San Francisco
# 3            77916.0      56120.71  San Francisco
# 4           134401.6        9737.0  San Francisco
# ...              ...           ...            ...
# 148649             0             0  San Francisco
# 148650  Not Provided  Not Provided  San Francisco
# 148651  Not Provided  Not Provided  San Francisco
# 148652  Not Provided  Not Provided  San Francisco
# 148653             0             0  San Francisco
#
# [148049 rows x 5 columns]

# %%
target_feature = 'TotalPay'
print(f"The target feature for analysis is: {target_feature}")
# Out:
# The target feature for analysis is: TotalPay

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Year', palette='viridis')
plt.title('Count of Employees by TotalPay')
plt.xlabel('TotalPay')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kle\AppData\Local\Temp\ipykernel_5188\2350190522.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Year', palette='viridis')

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='Year', y='TotalPay', palette='viridis')
plt.title('Average Total Pay by Year')
plt.xlabel('Year')
plt.ylabel('Average Total Pay')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kle\AppData\Local\Temp\ipykernel_5188\2093900701.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Year', y='TotalPay', palette='viridis')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
#Select features and target
x = df[['BasePay', 'OvertimePay', 'OtherPay']]
y = df['TotalPay']

# %%
# Split into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(x_test)

# %%
# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
# Out:
# C:\Users\kle\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_regression.py:1288: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
y_pred1 = model.predict([[	212739.13	,106088.18	,16452.60	]])
y_pred1
# Out:
# array([335279.91])

# %%
cr = df.select_dtypes(include=[np.number]).corr()
sns.heatmap(cr, annot=True, cmap='Blues')
plt.show()

# %%
r2_score(y_test,y_pred)
# Out:
# nan

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)  # Perfect prediction line
plt.title('Polynomial Regression: Predicted vs Actual TotalPay')
plt.xlabel('Actual TotalPay')
plt.ylabel('Predicted TotalPay')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure
plt.figure(figsize=(14, 6))

# Histogram for BasePay
plt.subplot(1, 2, 1)
sns.histplot(df['BasePay'].apply(pd.to_numeric, errors='coerce'),bins=50, kde=True, color='skyblue')
plt.title('Distribution of BasePay')
plt.xlabel('BasePay')
plt.ylabel('Frequency')

# Histogram for OvertimePay
plt.subplot(1, 2, 2)
sns.histplot(df['OvertimePay'].apply(pd.to_numeric, errors='coerce'),bins=50, kde=True, color='salmon')
plt.title('Distribution of OvertimePay')
plt.xlabel('OvertimePay')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
print(df.columns)
# Out:
# Index(['BasePay', 'OvertimePay', 'OtherPay', 'TotalPay'], dtype='str')

# %%
import matplotlib.pyplot as plt

# Count number of employees per Year
year_counts = df['Year'].value_counts()

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(year_counts, labels=year_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.viridis(np.linspace(0, 1, len(year_counts))))
plt.title('Employee Distribution by Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate average TotalPay per Year
year_avg = df.groupby('Year')['TotalPay'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(data=year_avg, x='Year', y='TotalPay', palette='viridis')
plt.title('Average TotalPay by Year')
plt.xlabel('Year')
plt.ylabel('Average TotalPay')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

agency_counts = df['Agency'].value_counts()

plt.figure(figsize=(10,5))
plt.bar(agency_counts.index, agency_counts.values)
plt.xlabel('Agency')
plt.ylabel('Count')
plt.title('Bar Graph for Agency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure
plt.figure(figsize=(14, 6))

# Histogram for BasePay
plt.subplot(1, 2, 1)
sns.histplot(df['BasePay'].apply(pd.to_numeric, errors='coerce'),bins=50, kde=True, color='skyblue')
plt.title('Distribution of BasePay')
plt.xlabel('BasePay')
plt.ylabel('Frequency')

# Histogram for OvertimePay
plt.subplot(1, 2, 2)
sns.histplot(df['OvertimePay'].apply(pd.to_numeric, errors='coerce'),bins=50, kde=True, color='salmon')
plt.title('Distribution of OvertimePay')
plt.xlabel('OvertimePay')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns
numeric_df = df.select_dtypes(include=np.number)

# Calculate correlation matrix
corr_matrix = numeric_df.corr(method='pearson')

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='flare', fmt='.2f')
plt.title("Feature Correlation Heatmap")
plt.show()
